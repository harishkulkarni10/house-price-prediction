# %% [markdown]
# #### Load the dataset

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/raw/AmesHousing.csv')

# %%
df.shape
# Out:
# (2930, 82)

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
df.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
df.describe().T
# Out:
#                   count          mean           std          min  \
# Order            2930.0  1.465500e+03  8.459625e+02          1.0
# PID              2930.0  7.144645e+08  1.887308e+08  526301100.0
# MS SubClass      2930.0  5.738737e+01  4.263802e+01         20.0
# Lot Frontage     2440.0  6.922459e+01  2.336533e+01         21.0
# Lot Area         2930.0  1.014792e+04  7.880018e+03       1300.0
# Overall Qual     2930.0  6.094881e+00  1.411026e+00          1.0
# Overall Cond     2930.0  5.563140e+00  1.111537e+00          1.0
# Year Built       2930.0  1.971356e+03  3.024536e+01       1872.0
# Year Remod/Add   2930.0  1.984267e+03  2.086029e+01       1950.0
# Mas Vnr Area     2907.0  1.018968e+02  1.791126e+02          0.0
# BsmtFin SF 1     2929.0  4.426296e+02  4.555908e+02          0.0
# BsmtFin SF 2     2929.0  4.972243e+01  1.691685e+02          0.0
# Bsmt Unf SF      2929.0  5.592625e+02  4.394942e+02          0.0
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(15749)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Pool QC           2917
# Misc Feature      2824
# Alley             2732
# Fence             2358
# Mas Vnr Type      1775
#                   ...
# Mo Sold              0
# Yr Sold              0
# Sale Type            0
# Sale Condition       0
# SalePrice            0
# Length: 82, dtype: int64

# %% [markdown]
# ###  **Grouping Features by Type**
#
# Before we proceed with encoding and feature engineering, it's important to categorize features based on their nature.
#
# - **Numerical features** can be used directly in regression models, but may require transformation (e.g., log).
# - **Categorical features** need to be encoded, using one-hot encoding or label encoding.
# - **Ordinal features** represent ordered categories and should be encoded using a ranking map, not dummy variables.
# - **Binary features** with only 2 values can be mapped to 0/1 directly.
#
# This grouping helps plan:
# - Preprocessing strategies (missing value fills, encoding)
# - Feature engineering logic (which variables can be combined)
# - Modeling accuracy (e.g., avoiding wrong encodings)

# %%
numerical_features = df.select_dtypes(include=["int64", "float64"]).columns.tolist()

categorical_features = df.select_dtypes(include=["object"]).columns.tolist()

binary_features = [col for col in df.columns if df[col].nunique() == 2]

ordinal_features = [
    "ExterQual", "ExterCond", "BsmtQual", "BsmtCond",
    "HeatingQC", "KitchenQual", "FireplaceQu",
    "GarageQual", "GarageCond", "PoolQC"
]

# %%
binary_features = list(set(binary_features) & set(categorical_features))

ordinal_features = list(set(ordinal_features) & set(categorical_features))

categorical_features = list(set(categorical_features) - set(ordinal_features) - set(binary_features))

# %%
print("Numerical features:", len(numerical_features))
print("Categorical features:", len(categorical_features))
print("Ordinal features:", len(ordinal_features))
print("Binary features:", len(binary_features))
# Out:
# Numerical features: 39
# Categorical features: 40
# Ordinal features: 0
# Binary features: 3

# %% [markdown]
# ### ** Target Variable (`SalePrice`) Distribution**
#
# Understanding the distribution of our target is essential for regression modeling.
#
# - `SalePrice` is **right-skewed** - there are a few very expensive properties.
# - Linear models (like Ridge, Lasso) assume the target is normally distributed.
# - A **log transformation** (`np.log1p()`) can help reduce skewness and improve model predictions.
# - Also helps identify **outliers** (extremely high prices) that might need handling later.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Original SalePrice distribution

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['SalePrice'], kde=True, color='skyblue')
plt.title('Distribution of SalePrice (Original)', fontsize=14)
plt.xlabel('SalePrice')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
skew_value = df['SalePrice'].skew()
print(f"Skewness of SalePrice: {skew_value:.2f}")
# Out:
# Skewness of SalePrice: 1.74

# %% [markdown]
# ##### Log transformed distribution

# %%
plt.figure(figsize=(12, 6))
sns.histplot(np.log1p(df['SalePrice']), kde=True, color='salmon')
plt.title('Distribution of SalePrice (Log Transformed)', fontsize=14)
plt.xlabel('Log(SalePrice)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ###  **Correlation Matrix of Numerical Features**
#
# This heatmap shows how strongly each numerical feature correlates with others, including `SalePrice`.
#
# Key benefits:
# - Helps identify **strong predictors** of house price.
# - Reveals **redundant features** (highly correlated with each other).
# - Informs **feature selection** and **feature engineering** decisions later.

# %%
numeric_df = df.select_dtypes(include=["int64", "float64"])

corr_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(16, 12))
sns.heatmap(corr_matrix, cmap="coolwarm", center=0, annot=False, fmt=".2f")
plt.title("Correlation Matrix of Numerical Features", fontsize=16)
plt.show()

# %%
cor_target = corr_matrix["SalePrice"].sort_values(ascending=False)

top_corr_features = cor_target[1:11].index.tolist()

top_corr_matrix = df[top_corr_features + ['SalePrice']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(top_corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", center=0)
plt.title("Top 10 Correlated Features with SalePrice", fontsize=14)
plt.show()

# %% [markdown]
# ##### **Multicollinearity Observations**
#
# While analyzing the correlation matrix, we identified a few pairs of independent features with very high correlation (above 0.8). Examples include:
#
# - `GarageCars` and `GarageArea` (0.89)
# - `TotalBsmtSF` and `1stFlrSF` (0.80)
# - `YearBuilt` and `GarageYrBlt` (0.83)
#
# These indicate **potential multicollinearity**, which can affect linear models by inflating the variance of coefficient estimates. However, since our project includes **regularized models** (Ridge, Lasso) and **tree-based models** (Gradient Boosting, XGBoost, LightGBM), we will **retain all features** for now.
#
# We'll revisit these relationships during model evaluation and interpretation, particularly for baseline linear regression. If needed, we will apply **VIF-bas**

# %% [markdown]
# ##### **Categorical Features vs SalePrice**
#
# We explore how categorical variables influence house prices using boxplots.
#
# - `Neighborhood`: Some areas (e.g., StoneBr, NridgHt) clearly command higher prices.
# - `HouseStyle`: 2-story houses tend to be priced higher than 1-story or split-level styles.
# - `KitchenQual`, `ExterQual`: As expected, higher quality ratings correspond to higher prices.
#
# These relationships will inform our **encoding strategy** (ordinal vs one-hot) and help in **feature selection**.

# %%
print(df.columns.tolist())
# Out:
# ['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Wood Dec
# ...

# %%
categorical_features = [
    'Neighborhood',
    'House Style',
    'Bldg Type',
    'Exter Qual',
    'Kitchen Qual'
]

for col in categorical_features:
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=col, y='SalePrice', data=df)
    plt.title(f'SalePrice by {col}')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# %% [markdown]
# ##### **Categorical Features vs SalePrice**
#
# We visualized key categorical features using boxplots:
#
# - `Neighborhood`: Significant price differences across localities.
# - `House Style`: 2-story homes tend to be priced higher.
# - `Kitchen Qual` and `Exter Qual`: Better quality ratings align with higher sale prices.
# - `Bldg Type`: Single-family homes dominate higher price ranges.

# %% [markdown]
# ##### **Numeric Feature Patterns**
#
# We explored key numeric predictors using boxplots against `SalePrice`:
#
# - `Overall Qual`: Strong positive trend — higher quality, higher price.
# - `Year Built`: Newer homes tend to have higher prices.
# - `Garage Cars`: More garage capacity → higher price, up to 3 cars.
# - `Total Bsmt SF`: Larger basements contribute positively but with diminishing returns.
#
# These patterns suggest that:
# - Some numeric features show ordinal-like behavior.
# - We can retain these variables directly or use them in feature engineering (e.g., `HouseAge = Yr Sold - Year Built`).

# %%
important_numeric = ['Overall Qual', 'Year Built', 'Garage Cars', 'Total Bsmt SF']

for col in important_numeric:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=col, y='SalePrice', data=df)
    plt.title(f'SalePrice by {col}')
    plt.grid(True)
    plt.show()

# %%
def detect_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

# Detect columns that have more than a given % of outliers
def get_columns_with_outliers(df, threshold=0.01):
    outlier_cols = []
    numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

    for col in numeric_cols:
        outliers = detect_outliers_iqr(df, col)
        if len(outliers) / len(df) > threshold:
            outlier_cols.append(col)

    return outlier_cols

outlier_columns = get_columns_with_outliers(df)
print("Columns with potential outliers:", outlier_columns)
# Out:
# Columns with potential outliers: ['MS SubClass', 'Lot Frontage', 'Lot Area', 'Overall Cond', 'Mas Vnr Area', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', '1st Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'TotRms AbvGrd', 'Garage Area', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Misc Val', 'SalePrice']

# %%
for col in outlier_columns:
    plt.figure(figsize=(5, 2))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.grid(True)
    plt.show()

# %% [markdown]
# ##### **Outlier Detection Summary**
#
# Using the IQR (Interquartile Range) method, the following features were found to contain significant outliers:
#
# - `Gr Liv Area`
# - `Lot Area`
# - `Garage Area`
#
# - These will be considered for capping, transformation, or removal during preprocessing, especially for linear models which are sensitive to outliers.
# - Tree-based models can handle them better, so no strict treatment may be needed there.

# %%
sns.boxplot(x=df["Gr Liv Area"])
# Out:
# <Axes: xlabel='Gr Liv Area'>

# %% [markdown]
# ### **Summary of Exploratory Data Analysis (EDA)**
#
# - The target variable `SalePrice` is right-skewed and will likely need transformation.
# - Certain features like `OverallQual`, `GrLivArea`, and `GarageCars` show strong positive correlation with price.
# - High multicollinearity exists between some features (e.g., `GarageCars` & `GarageArea`) — flagged for review in preprocessing.
# - Outliers are present in variables such as `GrLivArea`, `GarageArea`, and `LotArea`. These will be addressed during preprocessing.
# - Key categorical variables (e.g., `Neighborhood`, `HouseStyle`) show strong patterns with price and are candidates for encoding.
